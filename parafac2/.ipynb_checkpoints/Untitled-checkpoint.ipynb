# %%
from scipy.io import loadmat
x = loadmat('ml_factor.mat')

# %%
print(x['U'][0, 1])
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 1.14991182e-01 -1.50580868e-01  7.49352609e-02 -5.39806827e-01
#    1.12202014e-02]
#  [-4.53816722e-01  2.71645762e-01 -3.73982700e-02  2.62271544e-01
#   -1.44425788e-03]
#  [ 3.51947835e-01  4.83509536e-01 -8.59957919e-02  2.11348320e-01
#    2.81478479e-01]
#  [-3.58344966e-01 -3.35058422e-01 -2.17257590e-01 -2.64098777e-01
#    2.87489308e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
# ...
